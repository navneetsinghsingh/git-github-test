# %%
# control Flow
# conditional Statements
#if , if- elif, if- elif-else
# Transfer Satements
# Break, continume, pass
# iterative statements
# for while

# %%
# if condition:statement
# if condition:
#statement -1
#statement -2
#statement - 3
#name = input("enter name:")
#if name == "rama":
    #print("Hello Rama Good Morning")
#print("How are you")

# %%
#2>if- else:
if condition:
    Action-1
else:
    Acction-2
# if condition is true Action-1 will be executed oterwise Action-2 will be executed
#  name = input("enter Name:")


#
